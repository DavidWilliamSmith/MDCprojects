# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix

from sklearn.metrics import classification_report

# %%
from sklearn import datasets

# %%
iris_data=datasets.load_iris()

# %%
iris_df=pd.DataFrame(iris_data.data, columns= iris_data.feature_names)

# %%
iris_df['Y']= iris_data.target

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Y                  150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
iris_df['Y'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Y, dtype: int64

# %%
# How are the classes of Y called?

iris_data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ### Step by step logic to run KNN from scratch

# %% [markdown]
# Steps to do k-Nearest Neighbors:
#
# Step 1: Calculate Euclidean Distance
#
# - Standardize predictors!
#
# Step 2: Get Nearest Neighbors
#
# Step 3: Make Predictions

# %% [markdown]
# 1) Let's test our logic using the __last five observations from Iris as test data__ and __the first 145 obs for training__
#
# 2) Let's use K=10 to test our logic

# %%
from sklearn.preprocessing import scale

# 'scale()' allows us to standardize variables. Similar to 'StandardScaler()'. However, StandardScaler() requires an extra
# step compared to scale() when appplied outside of a pipeline application

# %%
iris_df.shape[0]
# Out:
# 150

# %% [markdown]
# Splitting the data: first 145 for training and the last five for testing

# %%
# Get all rows but the last five rows

X_train= iris_df.iloc[:-5,:-1]

# %%
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
#
# [145 rows x 4 columns]

# %%
X_train_standardized= scale(X_train)

# %%
y_train= iris_df.iloc[:-5,-1]

# %%
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    2
# 141    2
# 142    2
# 143    2
# 144    2
# Name: Y, Length: 145, dtype: int32

# %%
# Get the last five rows

X_test= iris_df.iloc[-5:,:-1]

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
X_test_standardized= scale(X_test)

# %%
y_test= iris_df.iloc[-5:,-1]

# %%
y_test
# Out:
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Y, dtype: int32

# %% [markdown]
# ### Step 1: Calculate the Euclidean Distance between the observations to classify (the test obs) and the training obs

# %% [markdown]
# - KNN requires that we compute the distance between each test obs and all training obs. We identify the K nearest neighbor to each test obs from these distances.
#
# - Let's compute these distances in a progressive way (which is better to understand the logic behind KNN)
#
# - First, let's compute the distance ONLY between the first test observation and ALL the training obs

# %%
# The following matrix contains the data for the five test observations
# It has five rows, one for each obs

X_test_standardized
# Out:
# array([[ 1.40069858,  0.070014  ,  0.15075567,  1.16554303],
#        [-0.07372098, -1.6803361 , -1.35680105, -0.77702869],
#        [ 0.6634888 ,  0.070014  ,  0.15075567, -0.29138576],
#        [-0.44232587,  1.47029409,  1.6583124 ,  1.16554303],
#        [-1.54814054,  0.070014  , -0.60302269, -1.26267162]])

# %%
# To retrieve ONLY the first test obs

X_test_standardized[0,:]
# Out:
# array([1.40069858, 0.070014  , 0.15075567, 1.16554303])

# %%
# Distance between the first test observation and the first training observation

np.sqrt(np.sum(np.square(X_test_standardized[0,:]- X_train_standardized[0,:])))
# Out:
# 3.7637646047330278

# %% [markdown]
# Knowing how to get the distance between the first test observation and the first training observation allows us to
# extend this logic and get the dist between the first test observation and all training observations

# %%
# Distance between first test obs and ALL training obs

distances_to_first=[]
for i in np.arange(X_train_standardized.shape[0]):
    distances_to_first.append(np.sqrt(np.sum(np.square(X_test_standardized[0,:]- X_train_standardized[i,:]))))

# %%
distances_to_first
# Out:
# [3.7637646047330278,
#  3.8060775847496964,
#  3.9922251561594533,
#  4.027704103038035,
#  3.899239781521412,
#  3.6742727513355735,
#  4.031002466685466,
#  3.7670674850212587,
#  4.2438133580144175,
#  3.866493274637933,
#  3.681965525309738,
#  3.904178026770895,
#  3.971315930758127,
#  4.451442307038944,
#  3.8501972691722317,
#  4.250570328185753,
#  3.759406379670419,
#  3.6788264629347465,
#  3.4725922527870123,
#  3.8882425079157708,
#  3.4379259174986556,
#  3.7195864220043315,
#  4.294479044979116,
#  3.356496573397705,
#  3.849142098916274,
#  3.6852129977589,
#  3.57863093017818,
#  3.6705790519006785,
#  3.641518773620929,
#  3.931110970478573,
#  3.8399576919837797,
#  3.3005759506141765,
#  4.309194688292124,
#  4.212413830554003,
#  3.7792155472190614,
#  3.7760537640622203,
#  3.51869112405242,
#  4.057138729253711,
#  4.246332887460031,
#  3.6919660858029513,
#  3.776472984079167,
#  4.458278311742238,
#  4.2486128281648785,
#  3.4773383223412915,
#  3.7335881383017817,
#  3.8041937747652925,
#  3.9491228177175404,
#  4.055308217995737,
#  3.7457435108547967,
#  3.7526481110928236,
#  0.9848074853564158,
#  1.089727706150286,
#  0.903119225178077,
#  2.7301982352200103,
#  1.2020887975598906,
#  1.9811639598392041,
#  1.2013630514751765,
#  3.29822740746499,
#  1.2339994272754335,
#  2.4844366879729143,
#  3.7313829105523286,
#  1.5205907280699682,
#  2.735743778091728,
#  1.4992872727496258,
#  2.0047556757851988,
#  0.960362365448292,
#  1.8599196374218154,
#  2.1876654394567696,
#  2.377607713083268,
#  2.489717389536061,
#  1.4532830724890016,
#  1.6051439443490803,
#  1.819751079768182,
#  1.739168804870392,
#  1.3101161466102107,
#  1.0313627924390218,
#  1.2045238802114842,
#  0.8463918496450771,
#  1.4931744820372486,
#  2.3812340895042423,
#  2.699912392452668,
#  2.7667645817413775,
#  2.0287516186041756,
#  1.7249141098586982,
#  2.078530769150717,
#  1.5371428630757147,
#  0.9066055594783834,
#  2.233743454313526,
#  1.957672975664871,
#  2.4528518674565767,
#  2.4066431976380134,
#  1.434697732282426,
#  2.1384079113987435,
#  3.325670066389323,
#  2.143604059332082,
#  1.933162692725336,
#  1.8980962870714961,
#  1.4547425476285152,
#  2.9781970417596164,
#  1.9601272286355969,
#  1.6088375860186208,
#  1.8139983538180677,
#  1.116658612853188,
#  1.354522483498968,
#  1.2237913328100822,
#  1.6666515746741215,
#  2.904176653808512,
#  1.469556789827837,
#  1.7641431050541072,
#  1.7917616637232419,
#  0.9064271602975499,
#  1.3789950199677043,
#  0.9186680238485525,
#  2.1370194980650816,
#  1.7645339444192947,
#  1.1141454649155107,
#  1.1160096222395306,
#  2.397547851131,
#  2.1942934713745985,
#  2.532903849102113,
#  1.0656726041383098,
#  1.8751170390740088,
#  1.879969871765156,
#  1.3673522602264143,
#  1.143222962095424,
#  1.2417048161732436,
#  1.2936721302674836,
#  1.25528895772197,
#  1.3399062468890959,
#  1.2335942202169699,
#  1.4691898829102352,
#  2.3840152289147176,
#  1.353090300198996,
#  1.4375798407683789,
#  1.9967243810362056,
#  1.5212868616427817,
#  1.5003043228892892,
#  1.1661202647262632,
#  1.3386031800376077,
#  0.8160608379765135,
#  1.0883003801454374,
#  0.7264870620364351,
#  1.8139983538180677,
#  1.1875454638922396,
#  1.2883394705505486]

# %%
# This list contains 145 elements. Why?

len(distances_to_first)
# Out:
# 145

# %% [markdown]
# Knowing how to get the distances between the first test observation and all training observations allows us to get the distance between each of the five test obs and all training obs

# %% [markdown]
# __Distance between each test obs and ALL training obs__
#
# I am saving all these distances in a list
#
# This list contains the distances between each of the five test obs and all training obs
#
# Later, we need to figure out a way of retrieving (separating) the distances that correspond to each test observation

# %%
distances=[]
for j in np.arange(X_test_standardized.shape[0]):
    for i in np.arange(X_train_standardized.shape[0]):
        distances.append(np.sqrt(np.sum(np.square(X_test_standardized[j,:] - X_train_standardized[i,:]))))

# %%
distances
# Out:
# [3.7637646047330278,
#  3.8060775847496964,
#  3.9922251561594533,
#  4.027704103038035,
#  3.899239781521412,
#  3.6742727513355735,
#  4.031002466685466,
#  3.7670674850212587,
#  4.2438133580144175,
#  3.866493274637933,
#  3.681965525309738,
#  3.904178026770895,
#  3.971315930758127,
#  4.451442307038944,
#  3.8501972691722317,
#  4.250570328185753,
#  3.759406379670419,
#  3.6788264629347465,
#  3.4725922527870123,
#  3.8882425079157708,
#  3.4379259174986556,
#  3.7195864220043315,
#  4.294479044979116,
#  3.356496573397705,
#  3.849142098916274,
#  3.6852129977589,
#  3.57863093017818,
#  3.6705790519006785,
#  3.641518773620929,
#  3.931110970478573,
#  3.8399576919837797,
#  3.3005759506141765,
#  4.309194688292124,
#  4.212413830554003,
#  3.7792155472190614,
#  3.7760537640622203,
#  3.51869112405242,
#  4.057138729253711,
#  4.246332887460031,
#  3.6919660858029513,
#  3.776472984079167,
#  4.458278311742238,
#  4.2486128281648785,
#  3.4773383223412915,
#  3.7335881383017817,
#  3.8041937747652925,
#  3.9491228177175404,
#  4.055308217995737,
#  3.7457435108547967,
#  3.7526481110928236,
#  0.9848074853564158,
#  1.089727706150286,
#  0.903119225178077,
#  2.7301982352200103,
#  1.2020887975598906,
#  1.9811639598392041,
#  1.2013630514751765,
#  3.29822740746499,
#  1.2339994272754335,
#  2.4844366879729143,
#  3.7313829105523286,
#  1.5205907280699682,
#  2.735743778091728,
#  1.4992872727496258,
#  2.0047556757851988,
#  0.960362365448292,
#  1.8599196374218154,
#  2.1876654394567696,
#  2.377607713083268,
#  2.489717389536061,
#  1.4532830724890016,
#  1.6051439443490803,
#  1.819751079768182,
#  1.739168804870392,
#  1.3101161466102107,
#  1.0313627924390218,
#  1.2045238802114842,
#  0.8463918496450771,
#  1.4931744820372486,
#  2.3812340895042423,
#  2.699912392452668,
#  2.7667645817413775,
#  2.0287516186041756,
#  1.7249141098586982,
#  2.078530769150717,
#  1.5371428630757147,
#  0.9066055594783834,
#  2.524744166463149,
#  2.869148341546284,
#  0.7794098967850194,
#  1.0177918465071683,
#  1.6683975188182192,
#  1.4340273567429256,
#  0.8037965624221516,
#  1.1711334685512442,
#  1.3296677241308434,
#  1.9602774275910173,
#  0.8157554083695634,
#  1.3360386952859071,
#  1.8190541055635765,
#  0.8046408000732941,
#  1.8497918595076228,
#  0.7492796038862692,
#  1.7853472656965266,
#  1.014950147888963,
#  3.551605276649549,
#  3.0094954389718533,
#  3.5448387994431414,
#  2.6904080882721977,
#  3.17927002097812,
#  2.3561300175061444,
#  3.0690443180786606,
#  1.9715732625833648,
#  3.0993544853540755,
#  2.095556120252023,
#  2.7947125899838787,
#  2.527107022281487,
#  2.9794698103716293,
#  2.742303746859738,
#  2.042167550583737,
#  3.1916763517921263,
#  2.3801545813240668,
#  2.201843520917421,
#  3.479460356632379,
#  2.3061418725342366,
#  2.937449841893895,
#  2.570718094746126,
#  3.2884586980432142,
#  2.647567506628411,
#  2.8509754391216102,
#  3.10165215287893,
#  3.429900949003443,
#  3.524682591362324,
#  2.6957866351573414,
#  2.124436909157561,
#  2.369797568989077,
#  2.291822418613212,
#  2.3011067219513963,
#  3.027881839912357,
#  2.260573941294419,
#  2.8362360095267416,
#  3.314486881670756,
#  3.2830656609954145,
#  2.0999954340238367,
#  2.4084840795669002,
#  2.29638613334083,
#  2.6917478011854383,
#  2.416043518439851,
#  2.1855991587313346,
#  2.292979410744683,
#  2.112834218177579,
#  2.230123522071687,
#  2.6668337273195393,
#  1.9189735439355513,
#  2.264411908090013,
#  4.179179620466347,
#  3.1620550762749273,
#  4.3735213697064985,
#  3.4445497225982686,
#  3.9609530263880757,
#  4.979442564727428,
#  2.6404133003807058,
#  4.457126073049302,
#  4.0180456750385405,
#  4.954240546972248,
#  3.6234099689289505,
#  3.6094124797330966,
#  4.032361911303242,
#  3.3354762057564047,
#  3.611126857018246,
#  3.865549791133525,
#  3.550546524975377,
#  5.403912612144525,
#  5.392877559779945,
#  3.446649360682087,
#  4.326374304826385,
#  3.0465437841679,
#  5.069601621082747,
#  3.362039817611089,
#  4.023111101653058,
#  4.276047791398143,
#  3.211551501510838,
#  3.0973342589164132,
#  3.803248413215512,
#  4.099586427579112,
#  4.587608637059608,
#  5.386128132721132,
#  3.89152079197996,
#  3.120823634601213,
#  3.1664247365776954,
#  5.089279642398788,
#  4.017896281003644,
#  3.4659449544244048,
#  3.002732680785115,
#  4.087137538560868,
#  4.231883263536745,
#  4.195035965007635,
#  3.1620550762749273,
#  4.295880969551717,
#  4.371865354004359]

# %%
len(distances)
# Out:
# 725

# %%
# 5 test obs
# 145 training obs
5*145
# Out:
# 725

# %%
np.array(distances).shape

# This is like a one column array with 725 elements (or rows)
# Out:
# (725,)

# %%
np.array(distances).ndim
# Out:
# 1

# %% [markdown]
# How to do__"figure out a way of retrieving (separating) the distances that correspond to each test observation"?__
#
# I found out a way of doing it using the __reshape method__
#
# The __distances__ list can be converted into a Numpy array and then reshaped from its current shape, which is 725 by 1, to a new array with shape 145 by 5 (= 145 training obs and five test observations). After the reshaping, each column should contain the distances for each of the five test obs.

# %%
# I realized that the reshape() method does not give me DIRECTLY what I want because ...
# it reshapes by filling out the rows first. 
# This is not what I want !!!

np.array(distances).reshape( X_train.shape[0], X_test.shape[0])

# X_train.shape[0]= 145
# X_test.shape[0]= 5
# Out:
# array([[3.7637646 , 3.80607758, 3.99222516, 4.0277041 , 3.89923978],
#        [3.67427275, 4.03100247, 3.76706749, 4.24381336, 3.86649327],
#        [3.68196553, 3.90417803, 3.97131593, 4.45144231, 3.85019727],
#        [4.25057033, 3.75940638, 3.67882646, 3.47259225, 3.88824251],
#        [3.43792592, 3.71958642, 4.29447904, 3.35649657, 3.8491421 ],
#        [3.685213  , 3.57863093, 3.67057905, 3.64151877, 3.93111097],
#        [3.83995769, 3.30057595, 4.30919469, 4.21241383, 3.77921555],
#        [3.77605376, 3.51869112, 4.05713873, 4.24633289, 3.69196609],
#        [3.77647298, 4.45827831, 4.24861283, 3.47733832, 3.73358814],
#        [3.80419377, 3.94912282, 4.05530822, 3.74574351, 3.75264811],
#        [0.98480749, 1.08972771, 0.90311923, 2.73019824, 1.2020888 ],
#        [1.98116396, 1.20136305, 3.29822741, 1.23399943, 2.48443669],
#        [3.73138291, 1.52059073, 2.73574378, 1.49928727, 2.00475568],
#        [0.96036237, 1.85991964, 2.18766544, 2.37760771, 2.48971739],
#        [1.45328307, 1.60514394, 1.81975108, 1.7391688 , 1.31011615],
#        [1.03136279, 1.20452388, 0.84639185, 1.49317448, 2.38123409],
#        [2.69991239, 2.76676458, 2.02875162, 1.72491411, 2.07853077],
#        [1.53714286, 0.90660556, 2.23374345, 1.95767298, 2.45285187],
#        [2.4066432 , 1.43469773, 2.13840791, 3.32567007, 2.14360406],
#        [1.93316269, 1.89809629, 1.45474255, 2.97819704, 1.96012723],
#        [1.60883759, 1.81399835, 1.11665861, 1.35452248, 1.22379133],
#        [1.66665157, 2.90417665, 1.46955679, 1.76414311, 1.79176166],
#        [0.90642716, 1.37899502, 0.91866802, 2.1370195 , 1.76453394],
#        [1.11414546, 1.11600962, 2.39754785, 2.19429347, 2.53290385],
#        [1.0656726 , 1.87511704, 1.87996987, 1.36735226, 1.14322296],
#        [1.24170482, 1.29367213, 1.25528896, 1.33990625, 1.23359422],
#        [1.46918988, 2.38401523, 1.3530903 , 1.43757984, 1.99672438],
#        [1.52128686, 1.50030432, 1.16612026, 1.33860318, 0.81606084],
#        [1.08830038, 0.72648706, 1.81399835, 1.18754546, 1.28833947],
#        [2.84657194, 1.92943182, 2.42754612, 2.31643935, 3.09607114],
#        [3.63794451, 2.85176789, 2.67315918, 2.16286823, 2.15411796],
#        [3.21299615, 2.76768155, 2.03441968, 2.42932616, 3.85884329],
#        [4.74503767, 3.63121817, 2.8259152 , 3.3973077 , 3.48374244],
#        [2.5556062 , 3.25112582, 3.27512664, 2.37956799, 2.7829235 ],
#        [1.8740687 , 2.63855816, 2.81684553, 2.59868601, 2.4331184 ],
#        [3.16674671, 1.43774546, 1.92494166, 2.04924131, 2.32257361],
#        [2.16493848, 2.40155982, 2.49365209, 2.05065205, 1.92725429],
#        [1.34968335, 0.85206651, 0.82249815, 0.65077984, 1.46691064],
#        [2.1961365 , 1.0042943 , 1.10624241, 0.84256549, 0.79438587],
#        [1.84978532, 0.97204392, 0.81206208, 0.95286443, 2.6953773 ],
#        [3.36801741, 2.26163572, 1.35396317, 2.20494827, 1.87165723],
#        [1.36183992, 1.69225445, 1.48915075, 1.05291972, 0.87966745],
#        [0.83605534, 1.10102451, 1.38638227, 1.27449807, 0.66927691],
#        [0.6689831 , 1.43041922, 2.52474417, 2.86914834, 0.7794099 ],
#        [1.01779185, 1.66839752, 1.43402736, 0.80379656, 1.17113347],
#        [1.32966772, 1.96027743, 0.81575541, 1.3360387 , 1.81905411],
#        [0.8046408 , 1.84979186, 0.7492796 , 1.78534727, 1.01495015],
#        [3.55160528, 3.00949544, 3.5448388 , 2.69040809, 3.17927002],
#        [2.35613002, 3.06904432, 1.97157326, 3.09935449, 2.09555612],
#        [2.79471259, 2.52710702, 2.97946981, 2.74230375, 2.04216755],
#        [3.19167635, 2.38015458, 2.20184352, 3.47946036, 2.30614187],
#        [2.93744984, 2.57071809, 3.2884587 , 2.64756751, 2.85097544],
#        [3.10165215, 3.42990095, 3.52468259, 2.69578664, 2.12443691],
#        [2.36979757, 2.29182242, 2.30110672, 3.02788184, 2.26057394],
#        [2.83623601, 3.31448688, 3.28306566, 2.09999543, 2.40848408],
#        [2.29638613, 2.6917478 , 2.41604352, 2.18559916, 2.29297941],
#        [2.11283422, 2.23012352, 2.66683373, 1.91897354, 2.26441191],
#        [4.17917962, 3.16205508, 4.37352137, 3.44454972, 3.96095303],
#        [4.97944256, 2.6404133 , 4.45712607, 4.01804568, 4.95424055],
#        [3.62340997, 3.60941248, 4.03236191, 3.33547621, 3.61112686],
#        [3.86554979, 3.55054652, 5.40391261, 5.39287756, 3.44664936],
#        [4.3263743 , 3.04654378, 5.06960162, 3.36203982, 4.0231111 ],
#        [4.27604779, 3.2115515 , 3.09733426, 3.80324841, 4.09958643],
#        [4.58760864, 5.38612813, 3.89152079, 3.12082363, 3.16642474],
#        [5.08927964, 4.01789628, 3.46594495, 3.00273268, 4.08713754],
#        [4.23188326, 4.19503597, 3.16205508, 4.29588097, 4.37186535]])

# %%
dist_matrix= np.array(distances).reshape(X_test.shape[0], X_train.shape[0]).T
print(dist_matrix.shape)
print(dist_matrix)
# Out:
# (145, 5)
# [[3.7637646  2.84657194 2.51771204 3.89768558 1.34968335]
#  [3.80607758 1.92943182 2.51101452 4.22153771 0.85206651]
#  [3.99222516 2.42754612 2.72081723 4.1570259  0.82249815]
#  [4.0277041  2.31643935 2.74050976 4.17383104 0.65077984]
#  [3.89923978 3.09607114 2.68328707 3.8921466  1.46691064]
#  [3.67427275 3.63794451 2.6413408  3.57591462 2.1961365 ]
#  [4.03100247 2.85176789 2.81482022 3.96250361 1.0042943 ]
#  [0.72648706 3.84230571 1.99939666 2.40155982 4.19503597]
#  [1.81399835 2.89452767 1.807909   2.49365209 3.16205508]
#  [1.18754546 4.17777856 2.16865776 2.05065205 4.29588097]
#  [1.28833947 4.34016359 2.35544406 1.92725429 4.37186535]]

# %% [markdown]
# So far, we have created a matrix called 'dist_matrix' with the distances between each of the five test obs and the 145 training obs. Each column of dist_matrix contains the distances for each of the test observations.

# %% [markdown]
# ### Step 2: Get the K nearest neighbors (10 nearest neighbors in this case) to each of the test obs that we want to classify

# %% [markdown]
# Let's use argsort() to get the indexes of the 10 nearest neighbors

# %%
x=np.array([6,9,1,10])

# %%
np.sort(x)
# Out:
# array([ 1,  6,  9, 10])

# %%
# argsort() gives us the indexes of the data when sorted from lowest to highest

x.argsort()
# Out:
# array([2, 0, 1, 3], dtype=int64)

# %%
# Get the index of the training observations that represent the 10 nearest neighbors to each of the five test observations

indexes=[]
for i in np.arange(dist_matrix.shape[1]):
    indexes.append(dist_matrix[:, i].argsort()[:10]) # the number 10 here means we are using 10 nearest neighbors

# %%
indexes
# Out:
# [array([141, 139,  77,  52, 110,  86, 112,  65,  50,  75], dtype=int64),
#  array([98, 79, 81, 93, 41, 80, 57, 62, 69, 60], dtype=int64),
#  array([74, 97, 75, 65, 58, 91, 51, 71, 63, 73], dtype=int64),
#  array([136, 100,  85,  70, 115, 124,  56, 110, 137, 144], dtype=int64),
#  array([ 3, 30, 29, 47, 34,  9, 38, 45, 12, 42], dtype=int64)]

# %%
type(indexes)
# Out:
# list

# %%
np.array(indexes).shape
# Out:
# (5, 10)

# %%
nei_index_matrix= np.array(indexes).reshape(dist_matrix.shape[1], 10).T
nei_index_matrix

# The 'nei_index_matrix' matrix contains the index of each of the 10 nearest neighbors to each of the five 
# test observations
# Out:
# array([[141,  98,  74, 136,   3],
#        [139,  79,  97, 100,  30],
#        [ 77,  81,  75,  85,  29],
#        [ 52,  93,  65,  70,  47],
#        [110,  41,  58, 115,  34],
#        [ 86,  80,  91, 124,   9],
#        [112,  57,  51,  56,  38],
#        [ 65,  62,  71, 110,  45],
#        [ 50,  69,  63, 137,  12],
#        [ 75,  60,  73, 144,  42]], dtype=int64)

# %% [markdown]
# ### Step 3: Make the prediction based on the classes of the nearest neighbors (= based on a majority rule applied on the classes of the nearest neighbors)

# %%
# Indexes of the 10 nearest neighbors to the first test observation

nei_index_matrix[:,0]
# Out:
# array([141, 139,  77,  52, 110,  86, 112,  65,  50,  75], dtype=int64)

# %%
# Y value (=class) the 10 nearest neighbors to the first test observation

y_train [nei_index_matrix[:,0]]
# Out:
# 141    2
# 139    2
# 77     1
# 52     1
# 110    2
# 86     1
# 112    2
# 65     1
# 50     1
# 75     1
# Name: Y, dtype: int32

# %% [markdown]
# What is the most frequent class among the 10 nearest neighbors to the first test obs?
#
# Let's obtain the mode!

# %%
import statistics as st

# %%
# Applying the majority rule to know how to classify the first test observation

st.mode(y_train [nei_index_matrix[:,0]])

# %%
# Alternative way of getting the mode

y_train [nei_index_matrix[:,0]].value_counts().idxmax()

# %% [markdown]
# The classification of the first test obs is Y=1 (versicolor)

# %% [markdown]
# CONTINUE FROM THIS POINT AND ON !!!!!

# %%
for i in np.arange(nei_index_matrix.shape[1]):
    print(y_train [nei_index_matrix[:,i]])

# %%
# Extend the logic not only to get the mode for the first test obs, but for all five test observations
# Looping through the nei_index_matrix will give us the prediction of Y for all five test observations

y_pred=[]
for i in np.arange(nei_index_matrix.shape[1]):
    y_pred.append(st.mode(y_train [nei_index_matrix[:,i]]))

# %%
y_pred

# %%
iris_data.target_names

# %%
iris_data.target_names[y_pred]

# %%
confusion_matrix(y_test, y_pred)

# %% [markdown]
# #### Checking that we applied KNN correctly
#
# #### To do that, we are going to apply KNN with K=10 using KNeighborsClassifier() and we are going to compare the results

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_standardized_v2= scaler.fit_transform(X_train)

# %%
X_train_standardized_v2
# Out:
# array([[-0.87257635,  1.00365344, -1.30520751, -1.28530043],
#        [-1.11265903, -0.13686183, -1.30520751, -1.28530043],
#        [-1.35274171,  0.31934428, -1.36173532, -1.28530043],
#        [-1.47278305,  0.09124122, -1.24867971, -1.28530043],
#        [-0.99261769,  1.23175649, -1.30520751, -1.28530043],
#        [-0.51245234,  1.91606565, -1.1356241 , -1.02019579],
#        [-1.47278305,  0.77555038, -1.30520751, -1.15274811],
#        [-0.99261769,  0.77555038, -1.24867971, -1.28530043],
#        [-1.71286573, -0.36496489, -1.30520751, -1.28530043],
#        [-1.11265903,  0.09124122, -1.24867971, -1.41785275],
#        [-0.51245234,  1.45985955, -1.24867971, -1.28530043],
#        [-1.23270037,  0.77555038, -1.1921519 , -1.28530043],
#        [-1.23270037, -0.13686183, -1.30520751, -1.41785275],
#        [-1.83290707, -0.13686183, -1.47479093, -1.41785275],
#        [-0.03228698,  2.14416871, -1.41826312, -1.28530043],
#        [-0.15232832,  3.05658093, -1.24867971, -1.02019579],
#        [-0.51245234,  1.91606565, -1.36173532, -1.02019579],
#        [-0.87257635,  1.00365344, -1.30520751, -1.15274811],
#        [-0.15232832,  1.6879626 , -1.1356241 , -1.15274811],
#        [-0.87257635,  1.6879626 , -1.24867971, -1.15274811],
#        [-0.51245234,  0.77555038, -1.1356241 , -1.28530043],
#        [-0.87257635,  1.45985955, -1.24867971, -1.02019579],
#        [-1.47278305,  1.23175649, -1.53131873, -1.28530043],
#        [-0.87257635,  0.54744733, -1.1356241 , -0.88764347],
#        [-1.23270037,  0.77555038, -1.02256849, -1.28530043],
#        [-0.99261769, -0.13686183, -1.1921519 , -1.28530043],
#        [-0.99261769,  0.77555038, -1.1921519 , -1.02019579],
#        [-0.75253501,  1.00365344, -1.24867971, -1.28530043],
#        [-0.75253501,  0.77555038, -1.30520751, -1.28530043],
#        [-1.35274171,  0.31934428, -1.1921519 , -1.28530043],
#        [-1.23270037,  0.09124122, -1.1921519 , -1.28530043],
#        [-0.51245234,  0.77555038, -1.24867971, -1.02019579],
#        [-0.75253501,  2.37227176, -1.24867971, -1.41785275],
#        [-0.392411  , -1.50548016,  0.05145979, -0.09232955],
#        [-0.392411  , -1.50548016, -0.00506801, -0.22488187],
#        [-0.03228698, -0.82117099,  0.1079876 ,  0.04022277],
#        [ 0.2077957 , -0.82117099,  0.78632125,  0.57043205],
#        [-0.51245234, -0.13686183,  0.44715443,  0.43787973],
#        [ 0.2077957 ,  0.77555038,  0.44715443,  0.57043205],
#        [ 1.04808507,  0.09124122,  0.56021003,  0.43787973],
#        [ 0.56791971, -1.73358321,  0.39062662,  0.17277509],
#        [-0.27236966, -0.13686183,  0.22104321,  0.17277509],
#        [-0.392411  , -1.2773771 ,  0.1645154 ,  0.17277509],
#        [-0.392411  , -1.04927405,  0.39062662,  0.04022277],
#        [ 0.32783704, -0.13686183,  0.50368223,  0.30532741],
#        [-0.03228698, -1.04927405,  0.1645154 ,  0.04022277],
#        [-0.99261769, -1.73358321, -0.23117923, -0.22488187],
#        [-0.27236966, -0.82117099,  0.27757101,  0.17277509],
#        [-0.15232832, -0.13686183,  0.27757101,  0.04022277],
#        [-0.15232832, -0.36496489,  0.27757101,  0.17277509],
#        [ 0.44787838, -0.36496489,  0.33409882,  0.17277509],
#        [-0.87257635, -1.2773771 , -0.40076264, -0.09232955],
#        [-0.15232832, -0.59306794,  0.22104321,  0.17277509],
#        [ 0.56791971,  0.54744733,  1.29507149,  1.76340293],
#        [-0.03228698, -0.82117099,  0.78632125,  0.96808901],
#        [ 1.52825043, -0.13686183,  1.23854369,  1.23319365],
#        [ 0.56791971, -0.36496489,  1.06896027,  0.83553669],
#        [ 0.80800239, -0.13686183,  1.18201588,  1.36574597],
#        [ 2.12845712, -0.13686183,  1.63423832,  1.23319365],
#        [-1.11265903, -1.2773771 ,  0.44715443,  0.70298437],
#        [ 1.7683331 , -0.36496489,  1.46465491,  0.83553669],
#        [ 1.04808507, -1.2773771 ,  1.18201588,  0.83553669],
#        [ 1.64829177,  1.23175649,  1.3515993 ,  1.76340293],
#        [ 0.80800239,  0.31934428,  0.78632125,  1.10064133],
#        [ 0.68796105, -0.82117099,  0.89937686,  0.96808901],
#        [ 1.16812641, -0.13686183,  1.01243247,  1.23319365],
#        [-0.15232832, -1.2773771 ,  0.72979345,  1.10064133],
#        [-0.03228698, -0.59306794,  0.78632125,  1.63085061],
#        [ 0.68796105,  0.31934428,  0.89937686,  1.49829829],
#        [ 0.80800239, -0.13686183,  1.01243247,  0.83553669],
#        [ 2.24849846,  1.6879626 ,  1.69076612,  1.36574597],
#        [ 2.24849846, -1.04927405,  1.80382173,  1.49829829],
#        [ 0.2077957 , -1.96168627,  0.72979345,  0.43787973],
#        [ 1.28816775,  0.31934428,  1.12548808,  1.49829829],
#        [-0.27236966, -0.59306794,  0.67326564,  1.10064133],
#        [ 2.24849846, -0.59306794,  1.69076612,  1.10064133],
#        [ 0.56791971, -0.82117099,  0.67326564,  0.83553669],
#        [ 1.04808507,  0.54744733,  1.12548808,  1.23319365],
#        [ 1.64829177,  0.31934428,  1.29507149,  0.83553669],
#        [ 0.32783704, -0.59306794,  0.56021003,  0.04022277],
#        [ 0.68796105, -0.36496489,  0.33409882,  0.17277509],
#        [ 0.92804373, -0.13686183,  0.39062662,  0.30532741],
#        [ 1.16812641, -0.59306794,  0.61673784,  0.30532741],
#        [ 1.04808507, -0.13686183,  0.72979345,  0.70298437],
#        [ 0.2077957 , -0.36496489,  0.44715443,  0.43787973],
#        [-0.15232832, -1.04927405, -0.11812362, -0.22488187],
#        [-0.392411  , -1.50548016,  0.05145979, -0.09232955],
#        [-0.392411  , -1.50548016, -0.00506801, -0.22488187],
#        [-0.03228698, -0.82117099,  0.1079876 ,  0.04022277],
#        [ 0.2077957 , -0.82117099,  0.78632125,  0.57043205],
#        [-0.51245234, -0.13686183,  0.44715443,  0.43787973],
#        [ 0.2077957 ,  0.77555038,  0.44715443,  0.57043205],
#        [ 1.04808507,  0.09124122,  0.56021003,  0.43787973],
#        [ 0.56791971, -1.73358321,  0.39062662,  0.17277509],
#        [-0.27236966, -0.13686183,  0.22104321,  0.17277509],
#        [-0.392411  , -1.2773771 ,  0.1645154 ,  0.17277509],
#        [-0.392411  , -1.04927405,  0.39062662,  0.04022277],
#        [ 0.32783704, -0.13686183,  0.50368223,  0.30532741],
#        [-0.03228698, -1.04927405,  0.1645154 ,  0.04022277],
#        [-0.99261769, -1.73358321, -0.23117923, -0.22488187],
#        [-0.27236966, -0.82117099,  0.27757101,  0.17277509],
#        [-0.15232832, -0.13686183,  0.27757101,  0.04022277],
#        [-0.15232832, -0.36496489,  0.27757101,  0.17277509],
#        [ 0.44787838, -0.36496489,  0.33409882,  0.17277509],
#        [-0.87257635, -1.2773771 , -0.40076264, -0.09232955],
#        [-0.15232832, -0.59306794,  0.22104321,  0.17277509],
#        [ 0.56791971,  0.54744733,  1.29507149,  1.76340293],
#        [-0.03228698, -0.82117099,  0.78632125,  0.96808901],
#        [ 1.52825043, -0.13686183,  1.23854369,  1.23319365],
#        [ 0.56791971, -0.36496489,  1.06896027,  0.83553669],
#        [ 0.80800239, -0.13686183,  1.18201588,  1.36574597],
#        [ 2.12845712, -0.13686183,  1.63423832,  1.23319365],
#        [-1.11265903, -1.2773771 ,  0.44715443,  0.70298437],
#        [ 1.7683331 , -0.36496489,  1.46465491,  0.83553669],
#        [ 1.04808507, -1.2773771 ,  1.18201588,  0.83553669],
#        [ 1.64829177,  1.23175649,  1.3515993 ,  1.76340293],
#        [ 0.80800239,  0.31934428,  0.78632125,  1.10064133],
#        [ 0.68796105, -0.82117099,  0.89937686,  0.96808901],
#        [ 1.16812641, -0.13686183,  1.01243247,  1.23319365],
#        [-0.15232832, -1.2773771 ,  0.72979345,  1.10064133],
#        [-0.03228698, -0.59306794,  0.78632125,  1.63085061],
#        [ 0.68796105,  0.31934428,  0.89937686,  1.49829829],
#        [ 0.80800239, -0.13686183,  1.01243247,  0.83553669],
#        [ 2.24849846,  1.6879626 ,  1.69076612,  1.36574597],
#        [ 2.24849846, -1.04927405,  1.80382173,  1.49829829],
#        [ 0.2077957 , -1.96168627,  0.72979345,  0.43787973],
#        [ 1.28816775,  0.31934428,  1.12548808,  1.49829829],
#        [-0.27236966, -0.59306794,  0.67326564,  1.10064133],
#        [ 2.24849846, -0.59306794,  1.69076612,  1.10064133],
#        [ 0.56791971, -0.82117099,  0.67326564,  0.83553669],
#        [ 1.04808507,  0.54744733,  1.12548808,  1.23319365],
#        [ 1.64829177,  0.31934428,  1.29507149,  0.83553669],
#        [ 0.44787838, -0.59306794,  0.61673784,  0.83553669],
#        [ 0.32783704, -0.13686183,  0.67326564,  0.83553669],
#        [ 0.68796105, -0.59306794,  1.06896027,  1.23319365],
#        [ 1.64829177, -0.13686183,  1.18201588,  0.57043205],
#        [ 1.88837444, -0.59306794,  1.3515993 ,  0.96808901],
#        [ 2.48858114,  1.6879626 ,  1.52118271,  1.10064133],
#        [ 0.68796105, -0.59306794,  1.06896027,  1.36574597],
#        [ 0.56791971, -0.59306794,  0.78632125,  0.43787973],
#        [ 0.32783704, -1.04927405,  1.06896027,  0.30532741],
#        [ 2.24849846, -0.13686183,  1.3515993 ,  1.49829829],
#        [ 0.56791971,  0.77555038,  1.06896027,  1.63085061],
#        [ 0.68796105,  0.09124122,  1.01243247,  0.83553669],
#        [ 0.2077957 , -0.13686183,  0.61673784,  0.83553669],
#        [ 1.28816775,  0.09124122,  0.95590467,  1.23319365],
#        [ 1.04808507,  0.09124122,  1.06896027,  1.63085061],
#        [ 1.28816775,  0.09124122,  0.78632125,  1.49829829],
#        [-0.03228698, -0.82117099,  0.78632125,  0.96808901],
#        [ 1.16812641,  0.31934428,  1.23854369,  1.49829829],
#        [ 1.04808507,  0.54744733,  1.12548808,  1.76340293]])

# %%
np.all(X_train_standardized_v2==X_train_standardized)
# Out:
# True

# %%
X_test_standardized_v2= scaler.fit_transform(X_test)

# %%
X_test_standardized_v2
# Out:
# array([[ 1.40069858,  0.070014  ,  0.15075567,  1.16554303],
#        [-0.07372098, -1.6803361 , -1.35680105, -0.77702869],
#        [ 0.6634888 ,  0.070014  ,  0.15075567, -0.29138576],
#        [-0.44232587,  1.47029409,  1.6583124 ,  1.16554303],
#        [-1.54814054,  0.070014  , -0.60302269, -1.26267162]])

# %%
X_test_standardized
# Out:
# array([[ 1.40069858,  0.070014  ,  0.15075567,  1.16554303],
#        [-0.07372098, -1.6803361 , -1.35680105, -0.77702869],
#        [ 0.6634888 ,  0.070014  ,  0.15075567, -0.29138576],
#        [-0.44232587,  1.47029409,  1.6583124 ,  1.16554303],
#        [-1.54814054,  0.070014  , -0.60302269, -1.26267162]])

# %%
pipe_knn= make_pipeline(StandardScaler(), KNeighborsClassifier(algorithm='brute', n_neighbors=10, weights= 'uniform'))

# %%
pipe_knn.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(algorithm='brute', n_neighbors=10))])

# %%
pipe_knn.predict(X_test)
# Out:
# array([2, 2, 2, 2, 1])

# %%
# https://medium.com/analytics-vidhya/why-it-makes-a-difference-how-to-standardize-training-and-test-set-e95bf350bed3
