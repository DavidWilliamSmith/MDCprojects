# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix

from sklearn.metrics import classification_report

# %%
from sklearn import datasets

# %%
iris_data=datasets.load_iris()

# %%
iris_df=pd.DataFrame(iris_data.data, columns= iris_data.feature_names)

# %%
iris_df['Y']= iris_data.target

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Y                  150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
iris_df['Y'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Y, dtype: int64

# %%
# How are the classes of Y called?

iris_data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ### Step by step logic to run KNN from scratch

# %% [markdown]
# Steps to do k-Nearest Neighbors:
#
# Step 1: Calculate Euclidean Distance
#
# - Standardize predictors!
#
# Step 2: Get Nearest Neighbors
#
# Step 3: Make Predictions

# %% [markdown]
# 1) Let's test our logic using the __last five observations from Iris as test data__ and __the first 145 obs for training__
#
# 2) Let's use K=10 to test our logic

# %% [markdown]
# __Note__:
#
# Lasse Schmidt published the following article with an excellent explanation about the right way of standardizing the train and test data:
#
# https://medium.com/analytics-vidhya/why-it-makes-a-difference-how-to-standardize-training-and-test-set-e95bf350bed3

# %% [markdown]
# __Splitting the data: first 145 observations for training and the last five for testing__
#
# __Also, let's standardize the data__

# %%
from sklearn.preprocessing import StandardScaler

# %%
train_scaler= StandardScaler()

# %%
# Get all rows but the last five rows

X_train= iris_df.iloc[:-5,:-1]

# %%
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
#
# [145 rows x 4 columns]

# %%
X_train_standardized= train_scaler.fit_transform(X_train)

# %%
y_train= iris_df.iloc[:-5,-1]

# %%
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    2
# 141    2
# 142    2
# 143    2
# 144    2
# Name: Y, Length: 145, dtype: int32

# %%
# Get the last five rows

X_test= iris_df.iloc[-5:,:-1]

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
X_test_standardized= train_scaler.transform(X_test)

# %%
y_test= iris_df.iloc[-5:,-1]

# %%
y_test
# Out:
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Y, dtype: int32

# %% [markdown]
# ### Step 1: Calculate the Euclidean Distance between the observations to classify (the five test obs in this example) and the training obs

# %% [markdown]
# - KNN requires that we compute the distance between each test obs and all training obs. We identify the K nearest neighbors to each test obs from these distances.
#
# - Let's compute these distances in a progressive way (which is better to understand the logic behind KNN)
#
# - First, let's compute the distance ONLY between the first test observation and ALL the training obs

# %%
# The following matrix contains the data for the five test observations
# It has five rows, one for each obs

X_test_standardized
# Out:
# array([[ 1.04808507, -0.13686183,  0.84284906,  1.49829829],
#        [ 0.56791971, -1.2773771 ,  0.72979345,  0.96808901],
#        [ 0.80800239, -0.13686183,  0.84284906,  1.10064133],
#        [ 0.44787838,  0.77555038,  0.95590467,  1.49829829],
#        [ 0.08775436, -0.13686183,  0.78632125,  0.83553669]])

# %%
# To retrieve ONLY the first test obs

X_test_standardized[0,:]
# Out:
# array([ 1.04808507, -0.13686183,  0.84284906,  1.49829829])

# %%
# Distance between the first test observation and the first training observation

np.sqrt(np.sum(np.square(X_test_standardized[0,:]- X_train_standardized[0,:])))
# Out:
# 4.165607307240199

# %%
import math

# %%
math.dist (X_test_standardized[0,:], X_train_standardized[0,:])
# Out:
# 4.165607307240199

# %% [markdown]
# Knowing how to get the distance between the first test observation and the first training observation allows us to
# extend this logic and get the dist between the first test observation and all training observations

# %%
# Distance between first test obs and ALL training obs

distances_to_first=[]
for i in np.arange(X_train_standardized.shape[0]):
    distances_to_first.append(np.sqrt(np.sum(np.square(X_test_standardized[0,:]- X_train_standardized[i,:]))))

# %%
distances_to_first
# Out:
# [4.165607307240199,
#  4.126909730613333,
#  4.3105344596209365,
#  4.304616298442756,
#  4.289539921237245,
#  4.111806989425734,
#  4.339293278758049,
#  4.137617456833658,
#  4.476320940023881,
#  4.195149047438195,
#  4.13614682514539,
#  4.2336897636702755,
#  4.280194637095968,
#  4.709087773311855,
#  4.385356793395608,
#  4.728252737672504,
#  4.225256554418218,
#  4.078223807014727,
#  3.9640105389705957,
#  4.2920233105242644,
#  3.864007104644589,
#  4.117737784944444,
#  4.648976951947716,
#  3.7100260699965952,
#  4.154838472297955,
#  4.006759101925164,
#  3.934590849458684,
#  4.082391722026684,
#  4.054293723095103,
#  4.226315650217812,
#  4.140490787996915,
#  3.739662825600934,
#  4.734597505813117,
#  4.682954435684832,
#  4.104115066267568,
#  4.1513421790842875,
#  3.9980517868044037,
#  4.4339615578548,
#  4.497939905214015,
#  4.07974885963016,
#  4.165751086858694,
#  4.6273276517142525,
#  4.521016191535016,
#  3.8320015294128713,
#  4.1038420492929575,
#  4.104165720379318,
#  4.348399159541459,
#  4.350341243798089,
#  4.182915069919243,
#  4.122537525208659,
#  1.3567894664770197,
#  1.2723502202100003,
#  1.1237956889570997,
#  2.615663659797332,
#  1.2269007142792043,
#  1.8875122020973083,
#  1.280491457977189,
#  3.265703264362036,
#  1.3922955196507443,
#  2.3819556255945096,
#  3.6414813526668657,
#  1.5382658629943833,
#  2.732317120517009,
#  1.4400876950506778,
#  2.0906133004061407,
#  1.2960384458698402,
#  1.739155672718244,
#  2.2341609548773245,
#  2.2296398924778438,
#  2.472750302546766,
#  1.2730822088905491,
#  1.715817455511527,
#  1.6384687688927333,
#  1.712527453753222,
#  1.4824165639563034,
#  1.281442379877224,
#  1.3026280120046123,
#  0.803309281145237,
#  1.4279982478712754,
#  2.4832049258030904,
#  2.6654340974852344,
#  2.76341423849033,
#  2.0740029846091925,
#  1.4277592273026527,
#  1.927780786681577,
#  1.598778371991639,
#  1.1208939918891325,
#  2.177520335970194,
#  1.9716122735344404,
#  2.364942346433357,
#  2.288670864467397,
#  1.4342143792268462,
#  2.141452914811382,
#  3.2919406960321282,
#  2.070852660294339,
#  1.9714248132138747,
#  1.889331715100484,
#  1.5582418420372186,
#  3.0110434017058187,
#  1.9475036805622137,
#  0.9867235683152389,
#  1.385568501225163,
#  0.6763235027734061,
#  0.8791865519553935,
#  0.4361696300493753,
#  1.3652037224226918,
#  2.599747801255582,
#  1.1818137271556883,
#  1.3620066654478729,
#  1.6007721488632805,
#  0.653521350679924,
#  0.9393005963276359,
#  0.33682180335889994,
#  1.7066575574066523,
#  1.1815639180283903,
#  0.5839595136203802,
#  0.7250180440595632,
#  2.3468084686431783,
#  1.7880035916750745,
#  2.274497644193811,
#  0.5879188059788616,
#  1.4624001835558982,
#  1.589405779064098,
#  1.0802079757209258,
#  0.7864123070539667,
#  1.1009678284128959,
#  1.0289564182747404,
#  0.9933623219042579,
#  0.6776577851343184,
#  1.1559489484197554,
#  1.2058851234119567,
#  2.4542373025085467,
#  0.6375811487287547,
#  1.2515453231484692,
#  1.6809399408852752,
#  1.3037711126675384,
#  1.063837968088845,
#  0.8060594164719407,
#  1.0938306318982705,
#  0.43901336694525356,
#  0.3474584919738036,
#  0.3359554855543591,
#  1.385568501225163,
#  0.6157176117729709,
#  0.7864123070539669]

# %%
# This list contains 145 elements. Why?

len(distances_to_first)
# Out:
# 145

# %% [markdown]
# Knowing how to get the distances between the first test observation and all training observations allows us to get the distance between each of the five test obs and all training obs

# %% [markdown]
# __Distance between each test obs and ALL training obs__
#
# I am saving all these distances in a list
#
# This list contains the distances between each of the five test obs and all training obs
#
# Later, we need to figure out a way of retrieving (separating) the distances that correspond to each test observation

# %%
distances=[]
for j in np.arange(X_test_standardized.shape[0]):
    for i in np.arange(X_train_standardized.shape[0]):
        distances.append(np.sqrt(np.sum(np.square(X_test_standardized[j,:] - X_train_standardized[i,:]))))

# %%
distances
# Out:
# [4.165607307240199,
#  4.126909730613333,
#  4.3105344596209365,
#  4.304616298442756,
#  4.289539921237245,
#  4.111806989425734,
#  4.339293278758049,
#  4.137617456833658,
#  4.476320940023881,
#  4.195149047438195,
#  4.13614682514539,
#  4.2336897636702755,
#  4.280194637095968,
#  4.709087773311855,
#  4.385356793395608,
#  4.728252737672504,
#  4.225256554418218,
#  4.078223807014727,
#  3.9640105389705957,
#  4.2920233105242644,
#  3.864007104644589,
#  4.117737784944444,
#  4.648976951947716,
#  3.7100260699965952,
#  4.154838472297955,
#  4.006759101925164,
#  3.934590849458684,
#  4.082391722026684,
#  4.054293723095103,
#  4.226315650217812,
#  4.140490787996915,
#  3.739662825600934,
#  4.734597505813117,
#  4.682954435684832,
#  4.104115066267568,
#  4.1513421790842875,
#  3.9980517868044037,
#  4.4339615578548,
#  4.497939905214015,
#  4.07974885963016,
#  4.165751086858694,
#  4.6273276517142525,
#  4.521016191535016,
#  3.8320015294128713,
#  4.1038420492929575,
#  4.104165720379318,
#  4.348399159541459,
#  4.350341243798089,
#  4.182915069919243,
#  4.122537525208659,
#  1.3567894664770197,
#  1.2723502202100003,
#  1.1237956889570997,
#  2.615663659797332,
#  1.2269007142792043,
#  1.8875122020973083,
#  1.280491457977189,
#  3.265703264362036,
#  1.3922955196507443,
#  2.3819556255945096,
#  3.6414813526668657,
#  1.5382658629943833,
#  2.732317120517009,
#  1.4400876950506778,
#  2.0906133004061407,
#  1.2960384458698402,
#  1.739155672718244,
#  2.2341609548773245,
#  2.2296398924778438,
#  2.472750302546766,
#  1.2730822088905491,
#  1.715817455511527,
#  1.6384687688927333,
#  1.712527453753222,
#  1.4824165639563034,
#  1.281442379877224,
#  1.3026280120046123,
#  3.3251655869001198,
#  3.765341723076523,
#  2.8379108338066605,
#  3.216539900147105,
#  3.095078332048629,
#  3.059051958296872,
#  3.2628270419594765,
#  3.2266119911517985,
#  3.2703912683931544,
#  3.194986354865546,
#  2.9627210586685004,
#  4.027509217940071,
#  4.073753294268941,
#  3.183112046925756,
#  3.2761975103900287,
#  3.2624271578815196,
#  3.5730050324859906,
#  3.514872657780198,
#  3.2239587655768944,
#  3.321957603189618,
#  3.7338033625415523,
#  3.544355204210766,
#  2.985369625791361,
#  3.3118038018134315,
#  3.1735421388486955,
#  3.5587252493752835,
#  3.3935002093274917,
#  3.421615902612546,
#  3.2415930430426787,
#  1.511281862589952,
#  0.917353412834749,
#  1.289936408906494,
#  1.8989400682158255,
#  0.982291768471714,
#  0.905566551774905,
#  0.9056735348774031,
#  2.3396374023317037,
#  1.1301570637183083,
#  1.3840605788828944,
#  2.883194781008774,
#  0.645722745801861,
#  2.2035253956082403,
#  0.6647697786714963,
#  1.1575563057987721,
#  1.1882601572934473,
#  0.6347082019723085,
#  1.388061865085702,
#  1.9320555667300754,
#  1.65877566108466,
#  0.4867058118589218,
#  1.0448249409496262,
#  1.3047016823932203,
#  0.9743788887275455,
#  1.027636681564246,
#  1.069477607058796,
#  1.2981556903916394,
#  0.9710821731058538,
#  0.582757342605335,
#  1.6830459860720335,
#  1.8720662404309616,
#  1.9632777117698097,
#  1.2551293673268116,
#  0.7436191382941241,
#  0.7958726473717083,
#  1.015982569887302,
#  1.0878986260136982,
#  1.8373636302970582,
#  0.9425929732287083,
#  1.535327099821033,
#  1.3609383871574638,
#  0.6470288938106359,
#  1.3660427227090433,
#  2.42415298174447,
#  1.1384410753440175,
#  0.9741615521008936,
#  0.898749375660629,
#  0.9085584076507377,
#  2.1196966971517255,
#  1.012203492888358,
#  1.3485549168866688,
#  0.7072899478279218,
#  1.5613023767324172,
#  0.6020586262212556,
#  0.9779843311825556,
#  2.2453423298681434,
#  1.6953971935244356,
#  1.8266122936391866,
#  1.5425901595804348,
#  2.342833358173903,
#  0.8928391310420281,
#  0.9267571390506468,
#  1.173226793692812,
#  1.1966163284681317,
#  0.9246935528841648,
#  1.010151770075134,
#  0.754906294511723,
#  3.016279445400108,
#  2.641187477996971,
#  1.8723569597299663,
#  1.4843865382017851,
#  0.6487490744735552,
#  2.401091436099644,
#  0.843575349096123,
#  1.2898369278442936,
#  1.7035926213550703,
#  0.6054517775702607,
#  0.26537004918321344,
#  0.8979910715556196,
#  1.631604030002748,
#  1.9461413335243527,
#  3.115165368534833,
#  0.9640429384546678,
#  0.7725372741850426,
#  1.118544787769472,
#  2.3297225760765827,
#  1.3324653351562454,
#  0.6807388361045816,
#  0.20777020278690783,
#  1.2961145406201975,
#  1.298720573266043,
#  1.3900633973032588,
#  0.7072899478279218,
#  1.4209454075869934,
#  1.53833806458434]

# %%
len(distances)
# Out:
# 725

# %%
# 5 test obs
# 145 training obs
5*145
# Out:
# 725

# %%
np.array(distances).shape

# This is like a one column array with 725 elements (or rows)
# Out:
# (725,)

# %% [markdown]
# How to do__"figure out a way of retrieving (separating) the distances that correspond to each test observation"?__
#
# I found out a way of doing it using the __reshape method__
#
# The __distances__ list can be converted into a Numpy array and then reshaped from its current shape, which is 725 by 1, to a new array with shape 145 by 5 (= 145 training obs and five test observations). After the reshaping, each column should contain the distances for each of the five test obs.

# %%
# I realized that the reshape() method does not give me DIRECTLY what I want because ...
# it reshapes by filling out the rows first. 
# This is not what I want !!!

np.array(distances).reshape( X_train.shape[0], X_test.shape[0])

# X_train.shape[0]= 145
# X_test.shape[0]= 5
# Out:
# array([[4.16560731, 4.12690973, 4.31053446, 4.3046163 , 4.28953992],
#        [4.11180699, 4.33929328, 4.13761746, 4.47632094, 4.19514905],
#        [4.13614683, 4.23368976, 4.28019464, 4.70908777, 4.38535679],
#        [4.72825274, 4.22525655, 4.07822381, 3.96401054, 4.29202331],
#        [3.8640071 , 4.11773778, 4.64897695, 3.71002607, 4.15483847],
#        [4.0067591 , 3.93459085, 4.08239172, 4.05429372, 4.22631565],
#        [4.14049079, 3.73966283, 4.73459751, 4.68295444, 4.10411507],
#        [4.15134218, 3.99805179, 4.43396156, 4.49793991, 4.07974886],
#        [4.16575109, 4.62732765, 4.52101619, 3.83200153, 4.10384205],
#        [4.10416572, 4.34839916, 4.35034124, 4.18291507, 4.12253753],
#        [1.35678947, 1.27235022, 1.12379569, 2.61566366, 1.22690071],
#        [1.8875122 , 1.28049146, 3.26570326, 1.39229552, 2.38195563],
#        [3.64148135, 1.53826586, 2.73231712, 1.4400877 , 2.0906133 ],
#        [1.29603845, 1.73915567, 2.23416095, 2.22963989, 2.4727503 ],
#        [1.27308221, 1.71581746, 1.63846877, 1.71252745, 1.48241656],
#        [1.28144238, 1.30262801, 0.80330928, 1.42799825, 2.48320493],
#        [2.6654341 , 2.76341424, 2.07400298, 1.42775923, 1.92778079],
#        [1.59877837, 1.12089399, 2.17752034, 1.97161227, 2.36494235],
#        [2.28867086, 1.43421438, 2.14145291, 3.2919407 , 2.07085266],
#        [1.97142481, 1.88933172, 1.55824184, 3.0110434 , 1.94750368],
#        [0.98672357, 1.3855685 , 0.6763235 , 0.87918655, 0.43616963],
#        [1.36520372, 2.5997478 , 1.18181373, 1.36200667, 1.60077215],
#        [0.65352135, 0.9393006 , 0.3368218 , 1.70665756, 1.18156392],
#        [0.58395951, 0.72501804, 2.34680847, 1.78800359, 2.27449764],
#        [0.58791881, 1.46240018, 1.58940578, 1.08020798, 0.78641231],
#        [1.10096783, 1.02895642, 0.99336232, 0.67765779, 1.15594895],
#        [1.20588512, 2.4542373 , 0.63758115, 1.25154532, 1.68093994],
#        [1.30377111, 1.06383797, 0.80605942, 1.09383063, 0.43901337],
#        [0.34745849, 0.33595549, 1.3855685 , 0.61571761, 0.78641231],
#        [4.06166494, 3.65295947, 3.96115084, 3.8768162 , 4.23674654],
#        [4.33570519, 4.12530702, 3.95498524, 3.90556925, 3.78213368],
#        [4.20140313, 4.02844658, 3.7916955 , 4.197339  , 4.66466878],
#        [0.51861267, 1.18517243, 2.15228256, 2.70021856, 2.95393263],
#        [0.97106579, 1.62169332, 2.41112033, 1.75586641, 0.71506509],
#        [1.48438654, 1.55801258, 1.16877873, 1.4190905 , 1.78481103],
#        [2.09424   , 2.33979361, 1.40039548, 1.74378098, 2.18640235],
#        [2.05701312, 0.2115694 , 0.98405643, 1.20184143, 1.11563692],
#        [0.92675714, 1.09687   , 1.75782773, 0.89820157, 0.71506509],
#        [3.33098376, 3.21145372, 3.37568512, 3.33563892, 3.45148701],
#        [3.42233492, 3.40522276, 3.26172942, 3.48808061, 3.27292166],
#        [3.39837406, 3.31487599, 3.3460211 , 3.72549762, 3.8178073 ],
#        [4.22382389, 3.55424386, 3.2481963 , 3.32186307, 3.51379064],
#        [3.06342425, 3.32516559, 3.76534172, 2.83791083, 3.2165399 ],
#        [3.09507833, 3.05905196, 3.26282704, 3.22661199, 3.27039127],
#        [3.19498635, 2.96272106, 4.02750922, 4.07375329, 3.18311205],
#        [3.27619751, 3.26242716, 3.57300503, 3.51487266, 3.22395877],
#        [3.3219576 , 3.73380336, 3.5443552 , 2.98536963, 3.3118038 ],
#        [3.17354214, 3.55872525, 3.39350021, 3.4216159 , 3.24159304],
#        [1.51128186, 0.91735341, 1.28993641, 1.89894007, 0.98229177],
#        [0.90556655, 0.90567353, 2.3396374 , 1.13015706, 1.38406058],
#        [2.88319478, 0.64572275, 2.2035254 , 0.66476978, 1.15755631],
#        [1.18826016, 0.6347082 , 1.38806187, 1.93205557, 1.65877566],
#        [0.48670581, 1.04482494, 1.30470168, 0.97437889, 1.02763668],
#        [1.06947761, 1.29815569, 0.97108217, 0.58275734, 1.68304599],
#        [1.87206624, 1.96327771, 1.25512937, 0.74361914, 0.79587265],
#        [1.01598257, 1.08789863, 1.83736363, 0.94259297, 1.5353271 ],
#        [1.36093839, 0.64702889, 1.36604272, 2.42415298, 1.13844108],
#        [0.97416155, 0.89874938, 0.90855841, 2.1196967 , 1.01220349],
#        [1.34855492, 0.70728995, 1.56130238, 0.60205863, 0.97798433],
#        [2.24534233, 1.69539719, 1.82661229, 1.54259016, 2.34283336],
#        [0.89283913, 0.92675714, 1.17322679, 1.19661633, 0.92469355],
#        [1.01015177, 0.75490629, 3.01627945, 2.64118748, 1.87235696],
#        [1.48438654, 0.64874907, 2.40109144, 0.84357535, 1.28983693],
#        [1.70359262, 0.60545178, 0.26537005, 0.89799107, 1.63160403],
#        [1.94614133, 3.11516537, 0.96404294, 0.77253727, 1.11854479],
#        [2.32972258, 1.33246534, 0.68073884, 0.2077702 , 1.29611454],
#        [1.29872057, 1.3900634 , 0.70728995, 1.42094541, 1.53833806]])

# %%
dist_matrix= np.array(distances).reshape(X_test.shape[0], X_train.shape[0]).T
print(dist_matrix.shape)
print(dist_matrix)
# Out:
# (145, 5)
# [[4.16560731 4.06166494 3.79894526 3.8284046  3.33098376]
#  [4.12690973 3.65295947 3.74109682 4.01607061 3.21145372]
#  [4.31053446 3.96115084 3.9280847  4.07065518 3.37568512]
#  [0.80605942 1.40889353 0.40679224 0.98405643 0.68073884]
#  [1.09383063 1.20864225 0.69401357 1.20184143 0.2077702 ]
#  [0.43901337 1.5853328  0.55941171 1.11563692 1.29611454]
#  [0.34745849 1.63032572 0.66476978 0.92675714 1.29872057]
#  [0.33595549 1.63590667 0.66627038 1.09687    1.3900634 ]
#  [1.3855685  0.75602082 1.09322037 1.75782773 0.70728995]
#  [0.61571761 1.85734109 0.80778625 0.89820157 1.42094541]
#  [0.78641231 2.0855794  1.02228004 0.71506509 1.53833806]]

# %% [markdown]
# So far, we have created a matrix called 'dist_matrix' with the distances between each of the five test obs and the 145 training obs. Each column of dist_matrix contains the distances for each of the test observations.

# %% [markdown]
# ### Step 2: Get the K nearest neighbors (10 nearest neighbors in this case) to each of the test obs that we want to classify

# %% [markdown]
# Let's use argsort() to get the indexes of the 10 nearest neighbors. Let's illustrate how argsort() works:

# %%
x=np.array([6,9,1,10])

# %%
np.sort(x)
# Out:
# array([ 1,  6,  9, 10])

# %%
# argsort() gives us the indexes of the data when sorted from lowest to highest

x.argsort()
# Out:
# array([2, 0, 1, 3], dtype=int64)

# %%
# Get the index of the training observations that represent the 10 nearest neighbors to each of the five test observations

indexes=[]
for i in np.arange(dist_matrix.shape[1]):
    indexes.append(dist_matrix[:, i].argsort()[:10]) # the number 10 here means we are using 10 nearest neighbors= the indexes for the 10 smallest values

# %%
indexes
# Out:
# [array([141, 112, 140, 104, 139, 115, 120, 143, 132, 110], dtype=int64),
#  array([123, 111,  72, 108,  83, 126, 113, 101, 142, 134], dtype=int64),
#  array([116, 137, 112, 104, 110,  77, 103, 128, 139, 127], dtype=int64),
#  array([136, 100, 115, 124, 144, 110, 143, 140,  70, 120], dtype=int64),
#  array([138, 127,  70,  78, 103, 126,  66,  61,  91, 121], dtype=int64)]

# %% [markdown]
# WE STOPPED HERE !!! CONTINUE ON 12-01 HERE !

# %%
type(indexes)
# Out:
# list

# %%
np.array(indexes).shape
# Out:
# (5, 10)

# %%
nei_index_matrix= np.array(indexes).reshape(dist_matrix.shape[1], 10).T
nei_index_matrix

# The 'nei_index_matrix' matrix contains the index of each of the 10 nearest neighbors to each of the five 
# test observations
# Out:
# array([[141, 123, 116, 136, 138],
#        [112, 111, 137, 100, 127],
#        [140,  72, 112, 115,  70],
#        [104, 108, 104, 124,  78],
#        [139,  83, 110, 144, 103],
#        [115, 126,  77, 110, 126],
#        [120, 113, 103, 143,  66],
#        [143, 101, 128, 140,  61],
#        [132, 142, 139,  70,  91],
#        [110, 134, 127, 120, 121]], dtype=int64)

# %% [markdown]
# ### Step 3: Make the prediction based on the classes of the nearest neighbors (= based on a majority rule applied on the classes of the nearest neighbors)

# %%
# Indexes of the 10 nearest neighbors to the first test observation

nei_index_matrix[:,0]
# Out:
# array([141, 112, 140, 104, 139, 115, 120, 143, 132, 110], dtype=int64)

# %%
# Y value (=class) the 10 nearest neighbors to the first test observation

y_train [nei_index_matrix[:,0]]
# Out:
# 141    2
# 112    2
# 140    2
# 104    2
# 139    2
# 115    2
# 120    2
# 143    2
# 132    2
# 110    2
# Name: Y, dtype: int32

# %% [markdown]
# What is the most frequent class among the 10 nearest neighbors to the first test obs?
#
# Let's obtain the mode!

# %%
import statistics as st

# %%
# Applying the majority rule to know how to classify the first test observation

st.mode(y_train [nei_index_matrix[:,0]])
# Out:
# 2

# %%
# Alternative way of getting the mode

y_train [nei_index_matrix[:,0]].value_counts().idxmax()
# Out:
# 2

# %% [markdown]
# The classification of the first test obs is Y=2 (virginica)

# %% [markdown]
# <br>
# Extend the logic not only to get the mode for the first test obs, but for all five test observations
#
# Looping through the nei_index_matrix will give us the prediction of Y for all five test observations

# %%
y_pred=[]
for i in np.arange(nei_index_matrix.shape[1]):
    y_pred.append(st.mode(y_train [nei_index_matrix[:,i]]))

# %%
y_pred
# Out:
# [2, 2, 2, 2, 2]

# %%
iris_data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[5]], dtype=int64)

# %%
iris_data.target_names[y_test]
# Out:
# array(['virginica', 'virginica', 'virginica', 'virginica', 'virginica'],
#       dtype='<U10')

# %%
confusion_matrix(iris_data.target_names[y_test], iris_data.target_names[y_pred])
# Out:
# array([[5]], dtype=int64)

# %% [markdown]
# #### Checking that we applied KNN correctly
#
# #### To do that, we are going to apply KNN with K=10 using KNeighborsClassifier() and we are going to compare the results

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe_knn= make_pipeline(StandardScaler(), KNeighborsClassifier(algorithm='brute', n_neighbors=10, weights= 'uniform'))

# %%
pipe_knn.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(algorithm='brute', n_neighbors=10))])

# %%
pipe_knn.predict(X_test)
# Out:
# array([2, 2, 2, 2, 1])

# %% [markdown]
# Apparently, there is a disagreement between our method from scratch and the scikit learn method but...
#
# Not a big deal !!!

# %% [markdown]
# Among the 10 nearest neighbors of the fifth test observation, there is a tie between y=1 and y=2 (there are five of each)
#
# The scikit-learn method chooses randomly when there is tie !

# %%
y_train [nei_index_matrix[:,4]]
# Out:
# 138    2
# 127    2
# 70     1
# 78     1
# 103    2
# 126    2
# 66     1
# 61     1
# 91     1
# 121    2
# Name: Y, dtype: int32

# %% [markdown]
# A tie only happens for the fifth test observation as we can see next:

# %%
for i in np.arange(nei_index_matrix.shape[1]):
    print(y_train [nei_index_matrix[:,i]])
# Out:
# 141    2
# 112    2
# 140    2
# 104    2
# 139    2
# 115    2
# 120    2
# 143    2
# 132    2
# 110    2
# Name: Y, dtype: int32
# 123    2
# 111    2
# 72     1
# 108    2
# 83     1
# 126    2
# 113    2
# 101    2
# 142    2
# 134    2
# Name: Y, dtype: int32
# 116    2
# 137    2
# 112    2
# 104    2
# 110    2
# 77     1
# 103    2
# 128    2
# 139    2
# 127    2
# Name: Y, dtype: int32
# 136    2
# 100    2
# 115    2
# 124    2
# 144    2
# 110    2
# 143    2
# 140    2
# 70     1
# 120    2
# Name: Y, dtype: int32
# 138    2
# 127    2
# 70     1
# 78     1
# 103    2
# 126    2
# 66     1
# 61     1
# 91     1
# 121    2
# Name: Y, dtype: int32
